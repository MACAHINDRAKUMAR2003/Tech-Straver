# %%
# !pip install apyori
# Out:
# Collecting apyori
#   Downloading apyori-1.1.2.tar.gz (8.6 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: apyori
#   Building wheel for apyori (setup.py) ... done
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5953 sha256=24ae43dcfac4f5830b2d9c20555154265792bdb04d532ed00c2ca1b02781b0ac
#   Stored in directory: /root/.cache/pip/wheels/c4/1a/79/20f55c470a50bb3702a8cb7c94d8ada15573538c7f4baebe2d
# Successfully built apyori
# Installing collected packages: apyori
# Successfully installed apyori-1.1.2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from apyori import apriori

# %%
store_data = pd.read_csv("/content/groceries - groceries.csv", header=None)
display(store_data.head())
print(store_data.shape)
# Out:
#         0               1                    2             3             4   \
# 0  Item(s)          Item 1               Item 2        Item 3        Item 4
# 1        4    citrus fruit  semi-finished bread     margarine   ready soups
# 2        3  tropical fruit               yogurt        coffee           NaN
# 3        1      whole milk                  NaN           NaN           NaN
# 4        4       pip fruit               yogurt  cream cheese  meat spreads
#
#        5       6       7       8       9   ...       23       24       25  \
# 0  Item 5  Item 6  Item 7  Item 8  Item 9  ...  Item 23  Item 24  Item 25
# 1     NaN     NaN     NaN     NaN     NaN  ...      NaN      NaN      NaN
# 2     NaN     NaN     NaN     NaN     NaN  ...      NaN      NaN      NaN
# 3     NaN     NaN     NaN     NaN     NaN  ...      NaN      NaN      NaN
# 4     NaN     NaN     NaN     NaN     NaN  ...      NaN      NaN      NaN
#
#         26       27       28       29       30       31       32
# 0  Item 26  Item 27  Item 28  Item 29  Item 30  Item 31  Item 32
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
# [5 rows x 33 columns]
# (9836, 33)

# %%
records = []
for i in range(1, 7501):
    records.append([str(store_data.values[i, j]) for j in range(0, 20)])

# %%
print(type(records))
# Out:
# <class 'list'>

# %%
association_rules = apriori(records, min_support=0.0045, min_confidence=0.2, min_lift=3, min_length=2)
association_results = list(association_rules)

# %%
print("There are {} Relation derived.".format(len(association_results)))
# Out:
# There are 133 Relation derived.

# %%
for i in range(0, len(association_results)):
    print(association_results[i][0])
# Out:
# frozenset({'fruit/vegetable juice', '10'})
# frozenset({'margarine', '10'})
# frozenset({'10', 'root vegetables'})
# frozenset({'other vegetables', '12'})
# frozenset({'other vegetables', '14'})
# frozenset({'whipped/sour cream', 'baking powder'})
# frozenset({'beef', 'root vegetables'})
# frozenset({'berries', 'whipped/sour cream'})
# frozenset({'liquor', 'bottled beer'})
# frozenset({'bottled beer', 'red/blush wine'})
# frozenset({'sugar', 'flour'})
# frozenset({'tropical fruit', 'grapes'})
# frozenset({'white bread', 'ham'})
# frozenset({'root vegetables', 'herbs'})
# frozenset({'processed cheese', 'white bread'})
# frozenset({'sliced cheese', 'sausage'})
# frozenset({'fruit/vegetable juice', 'nan', '10'})
# frozenset({'nan', 'margarine', '10'})
# frozenset({'nan', '10', 'root vegetables'})
# frozenset({'nan', '11', 'root vegetables'})
# frozenset({'other vegetables', '11', 'rolls/buns'})
# frozenset({'other vegetables', '11', 'whole milk'})
# frozenset({'nan', '12', 'other vegetables'})
# frozenset({'nan', '12', 'yogurt'})
# frozenset({'other vegetables', '12', 'whole milk'})
# frozenset({'nan', 'other vegetables', '13'})
# frozenset({'nan', 'other vegetables', '14'})
# frozenset({'nan', 'whole milk', '14'})
# frozenset({'nan', 'whipped/sour cream', 'baking powder'})
# frozenset({'other vegetables', 'whole milk', 'baking powder'})
# frozenset({'nan', 'beef', 'root vegetables'})
# frozenset({'other vegetables', 'beef', 'root vegetables'})
# frozenset({'rolls/buns', 'beef', 'root vegetables'})
# frozenset({'whole milk', 'beef', 'root vegetables'})
# frozenset({'yogurt', 'beef', 'root vegetables'})
# frozenset({'nan', 'berries', 'whipped/sour cream'})
# frozenset({'nan', 'liquor', 'bottled beer'})
# frozenset({'nan', 'bottled beer', 'red/blush wine'})
# frozenset({'domestic eggs', 'butter', 'whole milk'})
# frozenset({'other vegetables', 'whipped/sour cream', 'butter'})
# frozenset({'whipped/sour cream', 'butter', 'whole milk'})
# frozenset({'other vegetables', 'whipped/sour cream', 'chicken'})
# frozenset({'citrus fruit', 'other vegetables', 'root vegetables'})
# frozenset({'citrus fruit', 'pip fruit', 'tropical fruit'})
# frozenset({'citrus fruit', 'tropical fruit', 'root vegetables'})
# frozenset({'citrus fruit', 'whipped/sour cream', 'yogurt'})
# frozenset({'other vegetables', 'cream cheese', 'root vegetables'})
# frozenset({'other vegetables', 'cream cheese', 'yogurt'})
# frozenset({'yogurt', 'cream cheese', 'whole milk'})
# frozenset({'curd', 'other vegetables', 'root vegetables'})
# frozenset({'curd', 'root vegetables', 'yogurt'})
# frozenset({'curd', 'tropical fruit', 'yogurt'})
# frozenset({'curd', 'whipped/sour cream', 'whole milk'})
# frozenset({'margarine', 'domestic eggs', 'whole milk'})
# frozenset({'other vegetables', 'whipped/sour cream', 'domestic eggs'})
# frozenset({'nan', 'sugar', 'flour'})
# frozenset({'frozen vegetables', 'other vegetables', 'root vegetables'})
# frozenset({'fruit/vegetable juice', 'other vegetables', 'tropical fruit'})
# frozenset({'yogurt', 'hard cheese', 'whole milk'})
# frozenset({'nan', 'root vegetables', 'herbs'})
# frozenset({'nan', 'processed cheese', 'white bread'})
# frozenset({'nan', 'sliced cheese', 'sausage'})
# frozenset({'other vegetables', 'root vegetables', 'onions'})
# frozenset({'other vegetables', 'pip fruit', 'tropical fruit'})
# frozenset({'other vegetables', 'whipped/sour cream', 'pip fruit'})
# frozenset({'other vegetables', 'pork', 'root vegetables'})
# frozenset({'other vegetables', 'tropical fruit', 'root vegetables'})
# frozenset({'other vegetables', 'whipped/sour cream', 'sausage'})
# frozenset({'other vegetables', 'whipped/sour cream', 'tropical fruit'})
# frozenset({'other vegetables', 'whipped/sour cream', 'yogurt'})
# frozenset({'pip fruit', 'root vegetables', 'tropical fruit'})
# frozenset({'yogurt', 'pip fruit', 'tropical fruit'})
# frozenset({'rolls/buns', 'shopping bags', 'sausage'})
# frozenset({'whipped/sour cream', 'tropical fruit', 'root vegetables'})
# frozenset({'yogurt', 'tropical fruit', 'root vegetables'})
# frozenset({'yogurt', 'whipped/sour cream', 'root vegetables'})
# frozenset({'yogurt', 'whipped/sour cream', 'tropical fruit'})
# frozenset({'nan', '11', 'other vegetables', 'rolls/buns'})
# frozenset({'nan', '11', 'other vegetables', 'whole milk'})
# frozenset({'nan', '12', 'other vegetables', 'whole milk'})
# frozenset({'nan', 'other vegetables', 'beef', 'root vegetables'})
# frozenset({'nan', 'whole milk', 'beef', 'root vegetables'})
# frozenset({'nan', 'whipped/sour cream', 'other vegetables', 'butter'})
# frozenset({'other vegetables', 'butter', 'whole milk', 'yogurt'})
# frozenset({'citrus fruit', 'nan', 'domestic eggs', 'whole milk'})
# frozenset({'citrus fruit', 'nan', 'other vegetables', 'root vegetables'})
# frozenset({'citrus fruit', 'nan', 'pip fruit', 'tropical fruit'})
# frozenset({'citrus fruit', 'yogurt', 'nan', 'whipped/sour cream'})
# frozenset({'citrus fruit', 'other vegetables', 'root vegetables', 'tropical fruit'})
# frozenset({'citrus fruit', 'whole milk', 'other vegetables', 'root vegetables'})
# frozenset({'citrus fruit', 'other vegetables', 'whole milk', 'tropical fruit'})
# frozenset({'citrus fruit', 'other vegetables', 'whole milk', 'yogurt'})
# frozenset({'nan', 'other vegetables', 'cream cheese', 'yogurt'})
# frozenset({'nan', 'cream cheese', 'whole milk', 'yogurt'})
# frozenset({'curd', 'nan', 'tropical fruit', 'yogurt'})
# frozenset({'curd', 'nan', 'whole milk', 'whipped/sour cream'})
# frozenset({'nan', 'margarine', 'domestic eggs', 'whole milk'})
# frozenset({'other vegetables', 'whole milk', 'domestic eggs', 'root vegetables'})
# frozenset({'fruit/vegetable juice', 'other vegetables', 'whole milk', 'yogurt'})
# frozenset({'nan', 'other vegetables', 'root vegetables', 'onions'})
# frozenset({'nan', 'pip fruit', 'other vegetables', 'tropical fruit'})
# frozenset({'nan', 'pork', 'other vegetables', 'root vegetables'})
# frozenset({'nan', 'other vegetables', 'root vegetables', 'tropical fruit'})
# frozenset({'nan', 'pastry', 'sausage', 'yogurt'})
# frozenset({'nan', 'rolls/buns', 'shopping bags', 'sausage'})
# frozenset({'nan', 'whipped/sour cream', 'root vegetables', 'yogurt'})
# frozenset({'other vegetables', 'whole milk', 'pip fruit', 'root vegetables'})
# frozenset({'other vegetables', 'pip fruit', 'whole milk', 'tropical fruit'})
# frozenset({'other vegetables', 'pip fruit', 'whole milk', 'yogurt'})
# frozenset({'other vegetables', 'whole milk', 'rolls/buns', 'root vegetables'})
# frozenset({'other vegetables', 'whole milk', 'soda', 'root vegetables'})
# frozenset({'other vegetables', 'whole milk', 'tropical fruit', 'root vegetables'})
# frozenset({'other vegetables', 'tropical fruit', 'root vegetables', 'yogurt'})
# frozenset({'other vegetables', 'whole milk', 'whipped/sour cream', 'root vegetables'})
# frozenset({'other vegetables', 'whole milk', 'root vegetables', 'yogurt'})
# frozenset({'other vegetables', 'whipped/sour cream', 'tropical fruit', 'whole milk'})
# frozenset({'other vegetables', 'tropical fruit', 'whole milk', 'yogurt'})
# frozenset({'other vegetables', 'whipped/sour cream', 'whole milk', 'yogurt'})
# frozenset({'yogurt', 'whole milk', 'rolls/buns', 'root vegetables'})
# frozenset({'yogurt', 'rolls/buns', 'whole milk', 'tropical fruit'})
# frozenset({'yogurt', 'whole milk', 'tropical fruit', 'root vegetables'})
# frozenset({'yogurt', 'whipped/sour cream', 'tropical fruit', 'whole milk'})
# frozenset({'citrus fruit', 'root vegetables', 'other vegetables', 'nan', 'whole milk'})
# frozenset({'citrus fruit', 'other vegetables', 'tropical fruit', 'nan', 'whole milk'})
# frozenset({'fruit/vegetable juice', 'yogurt', 'other vegetables', 'nan', 'whole milk'})
# frozenset({'yogurt', 'other vegetables', 'pip fruit', 'nan', 'whole milk'})
# frozenset({'rolls/buns', 'root vegetables', 'other vegetables', 'nan', 'whole milk'})
# frozenset({'root vegetables', 'other vegetables', 'tropical fruit', 'nan', 'whole milk'})
# frozenset({'whipped/sour cream', 'root vegetables', 'other vegetables', 'nan', 'whole milk'})
# frozenset({'yogurt', 'root vegetables', 'other vegetables', 'nan', 'whole milk'})
# frozenset({'yogurt', 'other vegetables', 'tropical fruit', 'nan', 'whole milk'})
# frozenset({'yogurt', 'rolls/buns', 'tropical fruit', 'nan', 'whole milk'})
# frozenset({'yogurt', 'root vegetables', 'tropical fruit', 'nan', 'whole milk'})

# %%
for item in association_results:
    # first index of the inner list
    # Contains base item and add item
    pair = item[0]
    items = [x for x in pair]
    print("Rule: " + items[0] + " -> " + items[1])

    # second index of the inner list
    print("Support: " + str(item[1]))

    # third index of the list located at 0th
    # of the third index of the inner list

    print("Confidence: " + str(item[2][0][2]))
    print("Lift: " + str(item[2][0][3]))
    print("=====================================")
# Out:
# Rule: fruit/vegetable juice -> 10
# Support: 0.0061333333333333335
# Confidence: 0.25136612021857924
# Lift: 3.4655255544840884
# =====================================
# Rule: margarine -> 10
# Support: 0.0054666666666666665
# Confidence: 0.2240437158469945
# Lift: 3.734061930783242
# =====================================
# Rule: 10 -> root vegetables
# Support: 0.008133333333333333
# Confidence: 0.33333333333333326
# Lift: 3.01568154402895
# =====================================
# Rule: other vegetables -> 12
# Support: 0.0076
# Confidence: 0.6063829787234042
# Lift: 3.15605297739454
# =====================================
# Rule: other vegetables -> 14
# Support: 0.004933333333333333
# Confidence: 0.6491228070175438
# Lift: 3.3785017714306584
# =====================================
# Rule: whipped/sour cream -> baking powder
# Support: 0.005066666666666666
# Confidence: 0.2835820895522388
# Lift: 3.8811417365726113
# =====================================
# Rule: beef -> root vegetables
# Support: 0.0176
# Confidence: 0.3464566929133859
# Lift: 3.1344091638726104
# =====================================
# Rule: berries -> whipped/sour cream
# Support: 0.007733333333333333
# Confidence: 0.25
# Lift: 3.4215328467153285
# =====================================
# Rule: liquor -> bottled beer
# Support: 0.004533333333333334
# Confidence: 0.40963855421686746
# Lift: 5.086571451368387
# =====================================
# Rule: bottled beer -> red/blush wine
# Support: 0.004933333333333333
# Confidence: 0.2624113475177305
# Lift: 3.258419050302945
# =====================================
# Rule: sugar -> flour
# Support: 0.005066666666666666
# Confidence: 0.28787878787878785
# Lift: 8.636363636363635
# =====================================
# Rule: tropical fruit -> grapes
# Support: 0.006
# Confidence: 0.32608695652173914
# Lift: 3.1036195100419333
# =====================================
# Rule: white bread -> ham
# Support: 0.005333333333333333
# Confidence: 0.20833333333333331
# Lift: 4.82253086419753
# =====================================
# Rule: root vegetables -> herbs
# Support: 0.006533333333333334
# Confidence: 0.40495867768595045
# Lift: 3.6636792311756676
# =====================================
# Rule: processed cheese -> white bread
# Support: 0.0048
# Confidence: 0.30252100840336127
# Lift: 7.0028011204481775
# =====================================
# Rule: sliced cheese -> sausage
# Support: 0.006933333333333333
# Confidence: 0.30057803468208094
# Lift: 3.238987442694838
# =====================================
# Rule: fruit/vegetable juice -> nan
# Support: 0.0061333333333333335
# Confidence: 0.25136612021857924
# Lift: 3.5436953038333536
# =====================================
# Rule: nan -> margarine
# Support: 0.0054666666666666665
# Confidence: 0.2240437158469945
# Lift: 3.8016467621096353
# =====================================
# Rule: nan -> 10
# Support: 0.008133333333333333
# Confidence: 0.33333333333333326
# Lift: 3.0940594059405933
# =====================================
# Rule: nan -> 11
# Support: 0.005866666666666667
# Confidence: 0.3308270676691729
# Lift: 3.0707958013846497
# =====================================
# Rule: other vegetables -> 11
# Support: 0.004533333333333334
# Confidence: 0.25563909774436094
# Lift: 6.067383648995908
# =====================================
# Rule: other vegetables -> 11
# Support: 0.004933333333333333
# Confidence: 0.2781954887218045
# Lift: 3.7798300098071262
# =====================================
# Rule: nan -> 12
# Support: 0.0076
# Confidence: 0.6063829787234042
# Lift: 3.2185933053259244
# =====================================
# Rule: nan -> 12
# Support: 0.005066666666666666
# Confidence: 0.40425531914893614
# Lift: 3.0108390204737048
# =====================================
# Rule: other vegetables -> 12
# Support: 0.005066666666666666
# Confidence: 0.40425531914893614
# Lift: 5.492599444958372
# =====================================
# Rule: nan -> other vegetables
# Support: 0.004666666666666667
# Confidence: 0.5737704918032788
# Lift: 3.045490933138422
# =====================================
# Rule: nan -> other vegetables
# Support: 0.004933333333333333
# Confidence: 0.6491228070175438
# Lift: 3.4454501434052216
# =====================================
# Rule: nan -> whole milk
# Support: 0.005733333333333333
# Confidence: 0.7543859649122807
# Lift: 3.0047237051737152
# =====================================
# Rule: nan -> whipped/sour cream
# Support: 0.0048
# Confidence: 0.26865671641791045
# Lift: 3.8089326524278415
# =====================================
# Rule: other vegetables -> whole milk
# Support: 0.004533333333333334
# Confidence: 0.2537313432835821
# Lift: 3.447436729396496
# =====================================
# Rule: nan -> beef
# Support: 0.016666666666666666
# Confidence: 0.32808398950131235
# Lift: 3.0453340609651516
# =====================================
# Rule: other vegetables -> beef
# Support: 0.007333333333333333
# Confidence: 0.4044117647058823
# Lift: 3.6587312850351235
# =====================================
# Rule: rolls/buns -> beef
# Support: 0.0048
# Confidence: 0.3636363636363636
# Lift: 3.289834411667946
# =====================================
# Rule: whole milk -> beef
# Support: 0.008533333333333334
# Confidence: 0.42384105960264906
# Lift: 3.8345089831361494
# =====================================
# Rule: yogurt -> beef
# Support: 0.0048
# Confidence: 0.44444444444444436
# Lift: 4.020908725371934
# =====================================
# Rule: nan -> berries
# Support: 0.0076
# Confidence: 0.24568965517241378
# Lift: 3.4833126914803465
# =====================================
# Rule: nan -> liquor
# Support: 0.004533333333333334
# Confidence: 0.40963855421686746
# Lift: 5.103470359844694
# =====================================
# Rule: nan -> bottled beer
# Support: 0.004933333333333333
# Confidence: 0.2624113475177305
# Lift: 3.269244362762423
# =====================================
# Rule: domestic eggs -> butter
# Support: 0.0061333333333333335
# Confidence: 0.22222222222222224
# Lift: 3.4435261707988984
# =====================================
# Rule: other vegetables -> whipped/sour cream
# Support: 0.0061333333333333335
# Confidence: 0.3172413793103448
# Lift: 4.341807198590486
# =====================================
# Rule: whipped/sour cream -> butter
# Support: 0.006933333333333333
# Confidence: 0.25120772946859904
# Lift: 3.438061990902359
# =====================================
# Rule: other vegetables -> whipped/sour cream
# Support: 0.004533333333333334
# Confidence: 0.265625
# Lift: 3.635378649635036
# =====================================
# Rule: citrus fruit -> other vegetables
# Support: 0.010666666666666666
# Confidence: 0.37209302325581395
# Lift: 3.36634218868348
# =====================================
# Rule: citrus fruit -> pip fruit
# Support: 0.005733333333333333
# Confidence: 0.4056603773584906
# Lift: 3.8609807489704053
# =====================================
# Rule: citrus fruit -> tropical fruit
# Support: 0.005733333333333333
# Confidence: 0.32824427480916035
# Lift: 3.124152361762313
# =====================================
# Rule: citrus fruit -> whipped/sour cream
# Support: 0.005066666666666666
# Confidence: 0.46341463414634143
# Lift: 3.374378403978214
# =====================================
# Rule: other vegetables -> cream cheese
# Support: 0.004666666666666667
# Confidence: 0.5932203389830509
# Lift: 3.087545136969384
# =====================================
# Rule: other vegetables -> cream cheese
# Support: 0.006266666666666667
# Confidence: 0.4392523364485981
# Lift: 3.1984393430723164
# =====================================
# Rule: yogurt -> cream cheese
# Support: 0.0072
# Confidence: 0.4462809917355372
# Lift: 3.2496188718607075
# =====================================
# Rule: curd -> other vegetables
# Support: 0.0061333333333333335
# Confidence: 0.3407407407407408
# Lift: 3.0826966894518164
# =====================================
# Rule: curd -> root vegetables
# Support: 0.004666666666666667
# Confidence: 0.42168674698795183
# Lift: 3.070534565446251
# =====================================
# Rule: curd -> tropical fruit
# Support: 0.0052
# Confidence: 0.52
# Lift: 3.7864077669902914
# =====================================
# Rule: curd -> whipped/sour cream
# Support: 0.0061333333333333335
# Confidence: 0.2433862433862434
# Lift: 3.3310161047387328
# =====================================
# Rule: margarine -> domestic eggs
# Support: 0.0052
# Confidence: 0.20526315789473684
# Lift: 3.1807307525010877
# =====================================
# Rule: other vegetables -> whipped/sour cream
# Support: 0.005066666666666666
# Confidence: 0.22891566265060237
# Lift: 3.1329698355465654
# =====================================
# Rule: nan -> sugar
# Support: 0.0048
# Confidence: 0.2727272727272727
# Lift: 8.487363259147491
# =====================================
# Rule: frozen vegetables -> other vegetables
# Support: 0.006266666666666667
# Confidence: 0.3560606060606061
# Lift: 3.2212961947581973
# =====================================
# Rule: fruit/vegetable juice -> other vegetables
# Support: 0.006533333333333334
# Confidence: 0.31612903225806455
# Lift: 3.0088423121008683
# =====================================
# Rule: yogurt -> hard cheese
# Support: 0.004666666666666667
# Confidence: 0.4666666666666667
# Lift: 3.3980582524271843
# =====================================
# Rule: nan -> root vegetables
# Support: 0.006266666666666667
# Confidence: 0.38842975206611574
# Lift: 3.605474183782015
# =====================================
# Rule: nan -> processed cheese
# Support: 0.004666666666666667
# Confidence: 0.29411764705882354
# Lift: 7.047547453486188
# =====================================
# Rule: nan -> sliced cheese
# Support: 0.006666666666666667
# Confidence: 0.28901734104046245
# Lift: 3.159810579888438
# =====================================
# Rule: other vegetables -> root vegetables
# Support: 0.005733333333333333
# Confidence: 0.4174757281553398
# Lift: 3.7769215454343166
# =====================================
# Rule: other vegetables -> pip fruit
# Support: 0.009333333333333334
# Confidence: 0.37234042553191493
# Lift: 3.543849227778378
# =====================================
# Rule: other vegetables -> whipped/sour cream
# Support: 0.0054666666666666665
# Confidence: 0.5774647887323944
# Lift: 3.005541926088104
# =====================================
# Rule: other vegetables -> pork
# Support: 0.007066666666666666
# Confidence: 0.3419354838709677
# Lift: 3.093505583874859
# =====================================
# Rule: other vegetables -> tropical fruit
# Support: 0.013066666666666667
# Confidence: 0.368421052631579
# Lift: 3.3331217065583143
# =====================================
# Rule: other vegetables -> whipped/sour cream
# Support: 0.0052
# Confidence: 0.582089552238806
# Lift: 3.0296125203268875
# =====================================
# Rule: other vegetables -> whipped/sour cream
# Support: 0.008266666666666667
# Confidence: 0.2330827067669173
# Lift: 3.1900005488172987
# =====================================
# Rule: other vegetables -> whipped/sour cream
# Support: 0.010266666666666667
# Confidence: 0.23475609756097562
# Lift: 3.2129027950863454
# =====================================
# Rule: pip fruit -> root vegetables
# Support: 0.005333333333333333
# Confidence: 0.3333333333333333
# Lift: 3.1725888324873095
# =====================================
# Rule: yogurt -> pip fruit
# Support: 0.0064
# Confidence: 0.35036496350364965
# Lift: 3.334691911519508
# =====================================
# Rule: rolls/buns -> shopping bags
# Support: 0.005866666666666667
# Confidence: 0.2913907284768212
# Lift: 3.139986298241608
# =====================================
# Rule: whipped/sour cream -> tropical fruit
# Support: 0.005066666666666666
# Confidence: 0.22891566265060237
# Lift: 3.1329698355465654
# =====================================
# Rule: yogurt -> tropical fruit
# Support: 0.0088
# Confidence: 0.32038834951456313
# Lift: 3.0493814991868318
# =====================================
# Rule: yogurt -> whipped/sour cream
# Support: 0.0068
# Confidence: 0.24757281553398056
# Lift: 3.3883140812132373
# =====================================
# Rule: yogurt -> whipped/sour cream
# Support: 0.0068
# Confidence: 0.45945945945945943
# Lift: 3.345578588297035
# =====================================
# Rule: nan -> 11
# Support: 0.004533333333333334
# Confidence: 0.25563909774436094
# Lift: 6.224978029489309
# =====================================
# Rule: nan -> 11
# Support: 0.004933333333333333
# Confidence: 0.2781954887218045
# Lift: 3.9145706668171365
# =====================================
# Rule: nan -> 12
# Support: 0.005066666666666666
# Confidence: 0.40425531914893614
# Lift: 5.688395672827432
# =====================================
# Rule: nan -> other vegetables
# Support: 0.006533333333333334
# Confidence: 0.3602941176470588
# Lift: 3.344314210832848
# =====================================
# Rule: nan -> whole milk
# Support: 0.007733333333333333
# Confidence: 0.3841059602649007
# Lift: 3.56533997770638
# =====================================
# Rule: nan -> whipped/sour cream
# Support: 0.0048
# Confidence: 0.24827586206896549
# Lift: 3.5199791408643497
# =====================================
# Rule: other vegetables -> butter
# Support: 0.004533333333333334
# Confidence: 0.23448275862068965
# Lift: 4.137931034482759
# =====================================
# Rule: citrus fruit -> nan
# Support: 0.006
# Confidence: 0.20089285714285715
# Lift: 3.1130091499409684
# =====================================
# Rule: citrus fruit -> nan
# Support: 0.0096
# Confidence: 0.33488372093023255
# Lift: 3.108450379921713
# =====================================
# Rule: citrus fruit -> nan
# Support: 0.0052
# Confidence: 0.36792452830188677
# Lift: 3.6213044124201454
# =====================================
# Rule: citrus fruit -> yogurt
# Support: 0.0048
# Confidence: 0.4390243902439024
# Lift: 3.2697943662654096
# =====================================
# Rule: citrus fruit -> other vegetables
# Support: 0.004666666666666667
# Confidence: 0.267175572519084
# Lift: 7.533145841703496
# =====================================
# Rule: citrus fruit -> whole milk
# Support: 0.0061333333333333335
# Confidence: 0.21395348837209302
# Lift: 4.267689262741217
# =====================================
# Rule: citrus fruit -> other vegetables
# Support: 0.0052
# Confidence: 0.2549019607843137
# Lift: 3.463341858482523
# =====================================
# Rule: citrus fruit -> other vegetables
# Support: 0.005066666666666666
# Confidence: 0.23030303030303031
# Lift: 3.1291172595520425
# =====================================
# Rule: nan -> other vegetables
# Support: 0.0056
# Confidence: 0.42424242424242425
# Lift: 3.089143865842895
# =====================================
# Rule: nan -> cream cheese
# Support: 0.006266666666666667
# Confidence: 0.41964285714285715
# Lift: 3.0556518723994452
# =====================================
# Rule: curd -> nan
# Support: 0.004533333333333334
# Confidence: 0.45333333333333337
# Lift: 3.3763654419066533
# =====================================
# Rule: curd -> nan
# Support: 0.0056
# Confidence: 0.2222222222222222
# Lift: 3.1505986137366095
# =====================================
# Rule: nan -> margarine
# Support: 0.0052
# Confidence: 0.20526315789473684
# Lift: 3.254701235117392
# =====================================
# Rule: other vegetables -> whole milk
# Support: 0.004666666666666667
# Confidence: 0.21084337349397592
# Lift: 4.2056523968213275
# =====================================
# Rule: fruit/vegetable juice -> other vegetables
# Support: 0.0054666666666666665
# Confidence: 0.2645161290322581
# Lift: 4.667931688804554
# =====================================
# Rule: nan -> other vegetables
# Support: 0.0052
# Confidence: 0.3786407766990291
# Lift: 3.5146111698548497
# =====================================
# Rule: nan -> pip fruit
# Support: 0.008
# Confidence: 0.3191489361702128
# Lift: 3.1412296867146927
# =====================================
# Rule: nan -> pork
# Support: 0.0068
# Confidence: 0.32903225806451614
# Lift: 3.0541360587671673
# =====================================
# Rule: nan -> other vegetables
# Support: 0.011466666666666667
# Confidence: 0.3233082706766917
# Lift: 3.001004987716817
# =====================================
# Rule: nan -> pastry
# Support: 0.004533333333333334
# Confidence: 0.2833333333333333
# Lift: 3.05316091954023
# =====================================
# Rule: nan -> rolls/buns
# Support: 0.005866666666666667
# Confidence: 0.2913907284768212
# Lift: 3.185758693259707
# =====================================
# Rule: nan -> whipped/sour cream
# Support: 0.005733333333333333
# Confidence: 0.22279792746113988
# Lift: 3.0492417079535565
# =====================================
# Rule: other vegetables -> whole milk
# Support: 0.005333333333333333
# Confidence: 0.21276595744680848
# Lift: 4.2440018107741055
# =====================================
# Rule: other vegetables -> pip fruit
# Support: 0.0048
# Confidence: 0.23225806451612901
# Lift: 3.155680224403927
# =====================================
# Rule: other vegetables -> pip fruit
# Support: 0.0054666666666666665
# Confidence: 0.2180851063829787
# Lift: 3.848560700876095
# =====================================
# Rule: other vegetables -> whole milk
# Support: 0.0061333333333333335
# Confidence: 0.25555555555555554
# Lift: 3.472222222222222
# =====================================
# Rule: other vegetables -> whole milk
# Support: 0.004933333333333333
# Confidence: 0.26428571428571423
# Lift: 3.5908385093167694
# =====================================
# Rule: other vegetables -> whole milk
# Support: 0.007466666666666667
# Confidence: 0.21052631578947367
# Lift: 4.199328107502799
# =====================================
# Rule: other vegetables -> tropical fruit
# Support: 0.0054666666666666665
# Confidence: 0.2469879518072289
# Lift: 5.647590361445783
# =====================================
# Rule: other vegetables -> whole milk
# Support: 0.0054666666666666665
# Confidence: 0.3082706766917293
# Lift: 4.188460281137626
# =====================================
# Rule: other vegetables -> whole milk
# Support: 0.008533333333333334
# Confidence: 0.31067961165048547
# Lift: 4.221190375685944
# =====================================
# Rule: other vegetables -> whipped/sour cream
# Support: 0.004666666666666667
# Confidence: 0.3153153153153153
# Lift: 4.2841754798276535
# =====================================
# Rule: other vegetables -> tropical fruit
# Support: 0.008
# Confidence: 0.2255639097744361
# Lift: 3.980539584254755
# =====================================
# Rule: other vegetables -> whipped/sour cream
# Support: 0.005733333333333333
# Confidence: 0.28104575163398693
# Lift: 3.818556408070475
# =====================================
# Rule: yogurt -> whole milk
# Support: 0.004933333333333333
# Confidence: 0.20555555555555555
# Lift: 3.627450980392157
# =====================================
# Rule: yogurt -> rolls/buns
# Support: 0.005066666666666666
# Confidence: 0.20652173913043476
# Lift: 3.644501278772378
# =====================================
# Rule: yogurt -> whole milk
# Support: 0.0064
# Confidence: 0.2891566265060241
# Lift: 5.102763997165131
# =====================================
# Rule: yogurt -> whipped/sour cream
# Support: 0.005066666666666666
# Confidence: 0.3423423423423423
# Lift: 6.041335453100158
# =====================================
# Rule: citrus fruit -> root vegetables
# Support: 0.005333333333333333
# Confidence: 0.3053435114503817
# Lift: 4.296578491328073
# =====================================
# Rule: citrus fruit -> other vegetables
# Support: 0.004666666666666667
# Confidence: 0.22875816993464052
# Lift: 3.2189235919508516
# =====================================
# Rule: fruit/vegetable juice -> yogurt
# Support: 0.004666666666666667
# Confidence: 0.22580645161290325
# Lift: 4.1508538899430745
# =====================================
# Rule: yogurt -> other vegetables
# Support: 0.004666666666666667
# Confidence: 0.25547445255474455
# Lift: 3.5948562742224843
# =====================================
# Rule: rolls/buns -> root vegetables
# Support: 0.0056
# Confidence: 0.23333333333333334
# Lift: 3.283302063789869
# =====================================
# Rule: root vegetables -> other vegetables
# Support: 0.0061333333333333335
# Confidence: 0.27710843373493976
# Lift: 3.899274395895025
# =====================================
# Rule: whipped/sour cream -> root vegetables
# Support: 0.004533333333333334
# Confidence: 0.25563909774436094
# Lift: 3.5971730451833155
# =====================================
# Rule: yogurt -> root vegetables
# Support: 0.007066666666666666
# Confidence: 0.25728155339805825
# Lift: 3.6202845224867484
# =====================================
# Rule: yogurt -> other vegetables
# Support: 0.0068
# Confidence: 0.2328767123287671
# Lift: 3.2768768151327454
# =====================================
# Rule: yogurt -> rolls/buns
# Support: 0.004666666666666667
# Confidence: 0.4320987654320988
# Lift: 3.218213248004708
# =====================================
# Rule: yogurt -> root vegetables
# Support: 0.005333333333333333
# Confidence: 0.24096385542168672
# Lift: 4.429482636428065
# =====================================
